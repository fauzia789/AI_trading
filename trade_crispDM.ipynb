# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.440331  6.455077  6.391278  6.422877  493729600
# 2010-01-05  6.451465  6.487878  6.417459  6.458085  601904800
# 2010-01-06  6.348847  6.477046  6.342226  6.451466  552160000
# 2010-01-07  6.337110  6.379843  6.291067  6.372319  477131200
# 2010-01-08  6.379241  6.379843  6.291368  6.328683  447610800

# %%
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2019-12-23  68.757660  68.818186  67.878820  67.917557   98572000
# 2019-12-24  68.823036  68.973147  68.496201  68.924723   48478800
# 2019-12-26  70.188477  70.205426  68.927115  68.956166   93121200
# 2019-12-27  70.161850  71.171429  69.755116  70.481430  146266000
# 2019-12-30  70.578293  70.861558  69.053038  70.079558  144114400

# %%
# Out:
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 AAPL      AAPL      AAPL      AAPL       AAPL
# 0      2010-01-04  6.440331  6.455077  6.391278  6.422877  493729600
# 1      2010-01-05  6.451465  6.487878  6.417459  6.458085  601904800
# 2      2010-01-06  6.348847  6.477046  6.342226  6.451466  552160000
# 3      2010-01-07  6.337110  6.379843  6.291067  6.372319  477131200
# 4      2010-01-08  6.379241  6.379843  6.291368  6.328683  447610800

# %%
# Out:
# Price      Close      High       Low      Open
# Ticker      AAPL      AAPL      AAPL      AAPL
# 0       6.440331  6.455077  6.391278  6.422877
# 1       6.451465  6.487878  6.417459  6.458085
# 2       6.348847  6.477046  6.342226  6.451466
# 3       6.337110  6.379843  6.291067  6.372319
# 4       6.379241  6.379843  6.291368  6.328683

# %%
df
# Out:
# Price       Close       High        Low       Open
# Ticker       AAPL       AAPL       AAPL       AAPL
# 0        6.440331   6.455077   6.391278   6.422877
# 1        6.451465   6.487878   6.417459   6.458085
# 2        6.348847   6.477046   6.342226   6.451466
# 3        6.337110   6.379843   6.291067   6.372319
# 4        6.379241   6.379843   6.291368   6.328683
# ...           ...        ...        ...        ...
# 2510    68.757660  68.818186  67.878820  67.917557
# 2511    68.823036  68.973147  68.496201  68.924723
# 2512    70.188477  70.205426  68.927115  68.956166
# 2513    70.161850  71.171429  69.755116  70.481430
# 2514    70.578293  70.861558  69.053038  70.079558
#
# [2515 rows x 4 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       AAPL
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 2510    57.212838
# 2511    57.410470
# 2512    57.647437
# 2513    57.875337
# 2514    58.102497
#
# [2515 rows x 1 columns]

# %%
plt.figure(figsize= (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       AAPL
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 2510    52.164465
# 2511    52.291901
# 2512    52.425206
# 2513    52.555959
# 2514    52.685931
#
# [2515 rows x 1 columns]

# %%
plt.figure(figsize= (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')

# %%
df.shape
# Out:
# (2515, 4)

# %%
#Spliting data into training and testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1760, 1)
# (755, 1)

# %%
data_training.head()
# Out:
# Ticker      AAPL
# 0       6.440331
# 1       6.451465
# 2       6.348847
# 3       6.337110
# 4       6.379241

# %%
data_testing.head()
# Out:
# Ticker       AAPL
# 1760    26.996567
# 1761    26.786108
# 1762    26.862431
# 1763    26.832363
# 1764    26.968809

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array= scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.02760008],
#        [0.02806507],
#        [0.02377933],
#        ...,
#        [0.88408412],
#        [0.89123189],
#        [0.88640218]], shape=(1760, 1))

# %%
print(data_training_array.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(data_training_array.shape)
#
# NameError: name 'data_training_array' is not defined
